# %% [markdown]
# <a href="https://colab.research.google.com/github/yesesswi-whjr/Guess-a-number/blob/main/c108project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
datatoload=files.upload()
# Out:
#      <input type="file" id="files-b70a5f4f-270a-4571-94e1-7377aaf22082" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b70a5f4f-270a-4571-94e1-7377aaf22082">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data108hw.csv to data108hw (1).csv

# %%
import plotly.figure_factory as ff
import pandas as pd
import csv
df=pd.read_csv("data108hw.csv")
fig=ff.create_distplot([df["Avg Rating"].tolist()],["Avg Rating"],show_hist=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
